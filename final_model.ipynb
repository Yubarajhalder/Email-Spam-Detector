# %%
import joblib
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
model=joblib.load("final_model2.pkl")

# %%
feature_extraction = feature_extraction = joblib.load('tfidf_vectorizer.pkl')

# %%
mail_input=["Meeting Agenda for Thursday"]

# %%
mail_extraction = feature_extraction.transform(mail_input)
pred = model.predict(mail_extraction)
if pred == 0:
    print("Spam")
else:
    print("Ham")
# Out:
# Ham
